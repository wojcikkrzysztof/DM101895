# %%
import numpy as np
import pandas as pd
import matplotlib
from sklearn import datasets
iris = datasets.load_iris()

# %%
# %%file brain_size_part.csv
# "";"Sex";"FSIQ";"VIQ";"PIQ";"Weight";"Height";"MRI_Count"
# "1";"Female";133;132;124;"118";"64.5";816932
# "2";"Male";140;150;124;".";"72.5";1001121
# "3";"Male";139;123;150;"143";"73.3";1038437
# "4";"Male";133;129;128;"172";"68.8";965353
# "5";"Female";137;132;134;"147";"65.0";951545
# Out:
# Writing brain_size_part.csv

# %%
data = pd.read_csv("brain_size_part.csv", sep=";", na_values=".")

# %%
data

# %%
file = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
nazwy =['sepal_length','sepal_width','petal_length','petal_width','target']
iris = pd.read_csv(file, header=None, decimal='.',names=nazwy)

# %%
iris.describe()
iris.quantile([0.1,0.9])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0.1           4.8         2.50           1.4          0.2
# 0.9           6.9         3.61           5.8          2.2

# %%
# %matplotlib inline
iris.boxplot(["sepal_length", "petal_length"])
iris.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fdff4129048>,
# ...
#       dtype=object)

# %%
iris.target.unique()
c = iris["target"].unique()
len(c)
list(iris)
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'target'], dtype='object')

# %%
iris.plot(x="target")
iris.plot(x="sepal_length",kind="hist")
iris.plot(x="sepal_length",kind="box")
iris.plot(x="sepal_length",kind="kde")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-fc6b9451c2e0> in <module>()
#       3 iris.plot(x="sepal_length",kind="box")
#       4 iris.plot(x="sepal_length",kind="kde")
# ----> 5 iris["target"].plot(x="target",kind="bar")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# ...

# %%
iris["petal_length"].plot(kind="hist")

# %%
iris.plot(kind="scatter", x = "petal_length", y = "sepal_length", c = "blue")
